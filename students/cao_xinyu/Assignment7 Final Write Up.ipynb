# %% [markdown]
# # Data Preperation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
raw = pd.read_csv('gss2012.csv')
mask = raw['income06'].notnull()
df = raw[mask]
income_dict = {'$150000 OR OVER':15, '$110000 TO $129999':10, '$130000 TO $149999':13,
       '$50000 TO 59999':5, '$25000 TO 29999':2.5, '$30000 TO 34999':3.0,
       '$5 000 TO 5 999':0.5, 'UNDER $1 000':0.0, '$8 000 TO 9 999':0.8,
       '$22500 TO 24999':2.25, '$40000 TO 49999':4, '$60000 TO 74999':6,
       '$90000 TO $109999':9, '$75000 TO $89999':7.5, '$35000 TO 39999':3.5,
       '$15000 TO 17499':1.5, '$20000 TO 22499':2, '$6 000 TO 6 999':0.6,
       '$17500 TO 19999':1.75, '$12500 TO 14999':1.25, '$10000 TO 12499':1,
       '$1 000 TO 2 999':0.1, '$7 000 TO 7 999':0.7, '$4 000 TO 4 999':0.4,
       '$3 000 TO 3 999':0.3}
df['income'] = df['income06'].apply(lambda x: income_dict[x])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Introduction and Research Questions
# The General Social Survey provides a survey data on American's basic demographic information, such as income, sex, race and party affiliation. We want to understand if there is an inequality of different group of people. We first draw an income distribution of the whole data, we could see that most people have a income between 20 thousands to 80 thousands US dollar per year in figure 1.
#
# I want to ask three questions in this short essay, the first question is income inequality exist between male and female, and among races? By income inequality, I mean, is that white male have more density in the higher quantile of the income distribution and less density in the lower quantile of the income distribution in our survey dataset? The second question is how income, voting behavior, and political affiliation is correlated? That is does people of different income more likely to vote or more likely to support different political party? The third question is could we observe a retunr to education, more precisely, could we observe a pattern of return to education by observe a graduate increase of income with education gradually increase?
#
# ## Income Inequality of Gender
# In terms of income inequality of gender, we could see from figure 2 that men have a higher median income compared to female. In the violin plot of figure 2, more percentage of women is within the range of the lower income area, around than 25 000 us dollar per year. This violin plot of income distribution showed us an inequality between men and women.  However, there are some potential missing value problem might worth exploring, for example, it is more likely women are not in the labor force if they earn less, therefore those who could not earn a higher wage is already not in the labor market.  We could check our hypothesis to see if income women statistics are more likely to be of NA compared to men’s.
#
# ## Income Inequality of Race
# In terms of race, we could notice white has an around twice median income compared to the black from figure 5. White population has a much higher percentage of people are in the high quantile of the income distribution. While other race a lower percentage of the high quantile of income distribution compared to white, the black suffers the worst, it has only a tiny fraction of high income population compared to other two race categories. In terms of low end income quantile, that black has a large population who is below the 25 000 us dollars per year compared to other two races. The racial inequality exists in both median and upper quantile of income distribution.
#
# ## Income and Voting Behavior
# For people of different voting behavior for figure 3, we could observe an income gap between those who voted and those who did not vote. The group of people who voted in 2008 election has a nearly three times as much as median individual income compared to those who did not vote. Those who did not vote in 2008 election has much more people have income less than 2500. The upper level of those who did not vote is almost does not exist compared to those who voted. Clearly, we could see that income is closely related to the voting behavior.
#
# ## Income and Political Affiliation
# For political affiliation of figure 4, we could observe republican has higher median income, while democrats have lower median income. For the independent voters, their income is somehow in between republican and democrats. A more salient fact is that democrats has a higher portion of lower income individual supporter and republican has less lower income supporter.  The lower income quantile of Democrats characteristics is like the characteristics of income of minority groups such as black and women as we observed in pervious section of this essay.
#
# ## Return to Education
# In the last part, I want to talk something about the reward of the education. From figure 6, we could see that people does not finish high school has less than 20 000 us dollar median annual income. For people who finished the high school, the median is almost doubled to reach nearly 40 000 us dollar. For people finished junior college, the median income does not change much, but the upper 75% quantile income of the group improved form 60 000 us dollar to 80 000 us dollar. For those finished the bachelor degree, the median income is doubled again. For graduate degree, the payoff is not small. It improves from less than 80 000 to 90 000 us dollar, and more significantly the higher 75% quantile improve from 100 000 to 150 000, a 50% percent of increase. The outlier are also very interesting, for people who does not finish high school or just have high school diploma are also possible to reach higher income quantile, thought that is just a outlier in the distribution as we could see from the box plot in figure 6.
#
# This statistical does provide a correlation of education and income, but it does not imply that for a given person and then receives more education can earn more. Because it is possible that this result is just purely a self-selection bias. People who are either have higher social economical status or have a stronger ability could obtain more education, then it appears that people with more education has higher income. However, this does not reflect the person are make money because they receive education, they might earn the same if they does not receive those eudcation. We might be interested in further exploring on how education and income covariate.

# %%
sns.countplot(x='income', data=df)
plt.xlabel('Density')
plt.ylabel('Individual Income (in tens of thousands dollar)')
plt.title('Fig1: Income Bar Plot of GSS Survey Data')
plt.show()

# %%
sns.violinplot(x='sex', y='income', data=df)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Fig2: Income Violin Plot by Gender')
plt.show()

# %%
sns.violinplot(x='race', y='income', data=df)
plt.xlabel('Race')
plt.ylabel('Individual Income (in tens of thousands dollar)')
plt.title('Fig3: Income Box Plot by Race')
plt.show()

# %%
sns.violinplot(y='income', x='voted08', data=df)
plt.xlabel('Count')
plt.ylabel('Individual Income (in tens of thousands dollar)')
plt.title('Fig4: Income Box Plot by 2008 Voting')
plt.show()

# %%
my_sticks = ['Independent', 'Repulican', 'Democrats']
sns.violinplot(x='partyid_3', y='income', data=df)
plt.xlabel('Party Affliation')
plt.ylabel('Individual Income (in tens of thousands dollar)')
plt.title('Fig4: Income Box Plot by Different Party Affliation')
plt.xticks(np.array([0,1,2]), my_sticks)
plt.show()

# %%
degree_list = ['<HS', 'HS', 'Junior Coll', 'Bachelor deg','Graduate deg']
my_sticks = ['Not Finish High School', 'High School', 'Junior College', 'Bachelor','Graduate']
sns.boxplot(x='degree', y='income',  order=degree_list, data=df)
plt.xlabel('Highest Degree')
plt.ylabel('Individual Income (in tens of thousands dollar)')
plt.title('Fig5: Income Box Plot by Education Level')
plt.xticks(np.array([0,1,2,3,4]), my_sticks)
plt.show()
