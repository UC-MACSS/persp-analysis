# %% [markdown]
# ### Part 3 for Problem 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import matplotlib.mlab as mlab
import scipy.stats as st

# %%
movie = pd.read_csv("tmdb_5000_movies.csv")

# %%
movie.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# exclude outliers, majority clustering below 100
movie_sample1 = movie[movie.popularity <= 200] 
popularity = movie_sample1.popularity
vote = movie_sample1.vote_average

# %%
# %matplotlib inline
# explore the relationship between movies' popularity and voting average
plt.scatter(popularity, vote)
minorLocator = MultipleLocator(1)
ax.xaxis.set_minor_locator(minorLocator)
plt.grid(b=True, which='major', color='0.65', linestyle='-')
plt.title("Movies' voting average and popularity", fontsize=10)
plt.xlabel(r'Popularity')
plt.ylabel(r'Voting average')

# %%
# exclude outliers, majority clustering below 1.5 billion
movie_sample2 = movie[(movie.revenue <= 1500000000)] 
revenue = movie_sample2.revenue
vote = movie_sample2.vote_average
# %matplotlib inline
# explore the relationship between movies' revenue and voting average
plt.scatter(revenue, vote)
minorLocator = MultipleLocator(1)
ax.xaxis.set_minor_locator(minorLocator)
plt.grid(b=True, which='major', color='0.65', linestyle='-')
plt.title("Movies' voting average and revenue", fontsize=10)
plt.xlabel(r'Revenue (billion USD)')
plt.ylabel(r'Voting average')

# %%
# exclude outliers, majority clustering below 150 million
movie_sample3 = movie[(movie.budget <= 150000000)] 
budget = movie_sample3.revenue
vote = movie_sample3.vote_average
# %matplotlib inline
# explore the relationship between movies' budget and voting average
plt.scatter(budget, vote)
minorLocator = MultipleLocator(1)
ax.xaxis.set_minor_locator(minorLocator)
plt.grid(b=True, which='major', color='0.65', linestyle='-')
plt.title("Movies' voting average and budget", fontsize=10)
plt.xlabel(r'Revenue ( 100 million USD)')
plt.ylabel(r'Voting average')
