# %% [markdown]
# # Exploring the General Social Survey
# ## Kevin Sun
# ## November 22, 2017
# ## Perspectives in Computational Analysis

# %% [markdown]
# ## Loading the data
#
# #### Note: Questions explored are identified within comments in the code

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
df = pd.read_csv("gss2012.csv")

# %% [markdown]
# ## Generating basic histograms

# %%
pd.DataFrame.hist(df, column="childs", bins = 20)
plt.grid(True)
plt.xlabel('children')
plt.ylabel('children count')
plt.title('Histogram of # of children')
# generating bins with $ of children people have
# Question - what is the distribution of # of children people have in the U.S.?

# %%
pd.DataFrame.hist(df, column="childs", bins = 5)
plt.grid(True)
plt.xlabel('children')
plt.ylabel('children count')
plt.title('Histogram of # of children')
# changing bin size from previous graph

# %%
pd.DataFrame.hist(df, column="age", bins = 50)
plt.grid(True)
plt.xlabel('age')
plt.ylabel('age count')
plt.title('Histogram of age')
# generating counts of peoples' ages
# Question - what is the distribution of people's ages in the U.S.?

# %%
pd.DataFrame.hist(df, column="age", bins = 100)
plt.grid(True)
plt.xlabel('age')
plt.ylabel('age count')
plt.title('Histogram of age')
# increasing the number of bins from previous graph
# Observation - odd number of spikes at particular ages, shouldn't it be smoother?

# %%
pd.DataFrame.hist(df, column="age", bins = 10)
plt.grid(True)
plt.xlabel('age')
plt.ylabel('count')
plt.title('Histogram of age')

# %% [markdown]
# ## Generating multiple histograms & overlaying

# %%
pd.DataFrame.hist(df, column=["age", "childs"], bins = 10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c8e861c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c8e9efa90>]], dtype=object)

# %%
pd.DataFrame.hist(df, column=["age", "childs", "tvhours"], bins = 10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c8eb5bfd0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c8edab6a0>]], dtype=object)

# %%
df_3 = df[['age', 'childs', 'tvhours']]
df_3.plot.hist(alpha=0.25)

# %% [markdown]
# ## Generating basic boxplots

# %%
bp = df.boxplot("age") #age distribution of data set

# %%
bp2 = df.boxplot("age", "childs") 
# age by number of children had
# Observation - wouldn't we expect median age to plateau even as number of children increase?

# %%
bp3 = df.boxplot("age", "tvhours") 
#age by amount of tv watched

# %%
bp4 = df.boxplot("tvhours", "age") 
# amount of tv watched by age

# %%
bp5 = df.boxplot("tvhours", "marital") 
# amount of tv watched by marital status
# Question - are non-married people watching more television?

# %%
bp6 = df.boxplot("childs", "marital") 
#number of children had by marital status

# %%
bp7 = df.boxplot("childs", "educ") #number of children had by education level

# %%
bp8 = df.boxplot("childs", "natfare") 

# comparing # of children with views on welfare
# Observation - regardless of the number of children people have, their views on welfare remain the same???

# %%
bp9 = df.boxplot("age", "natfare") #comparing welare views on age

# %%
bp10 = df.boxplot("tvhours", "natfare") 
# comparing views on national welfare by tv watched

# %%
bp10 = df.boxplot("age", "polviews") 
# Comparing self-reporting political views by age
# Question - does the median age differ when comparing peoples' political viewpoints?

# %%
bp11 = df.boxplot("age", "natsoc") 
#Comparing views on social security with age
#Observation - we would expect younger people to believe too much is being spent on social security given they
#are less affected by the insurance program

# %%
bp12 = df.boxplot("age", "partyid") 
# Comparing political party affiliation by age
# Observation - as expected - the median age for strongly identified republicans is the oldest out of all groups

# %%
bp13 = df.boxplot("age", "natrace") #Comparing views on improving conditions of black Americans by age

# %%
bp14 = df.boxplot("age", "natarms") #Comparing views on defense/military by age

# %%
bp15 = df.boxplot("age", "gunlaw") #Comparing viewpoints on gun permits by age

# %% [markdown]
# ## Generating Scatterplots

# %%
df.plot.scatter('age', 'childs', color ="Green") #plotting relationship between age and # of children

# %%
df.plot.scatter('age', 'tvhours') # plotting relationship between age and tv hours

# %% [markdown]
# ## Generating Visuals with Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ## Compiling counts with bar charts

# %%
sns.countplot(x="race", data=df, palette="cubehelix") #race of survey respondents overrepresents whites

# %%
sns.countplot(x="sex", data=df, palette="cubehelix") #sex of survey respondents

# %%
sns.countplot(x="partyid", data=df, palette="cubehelix") #comparing counts on party id of population

# %%
sns.countplot(y="degree", data=df, palette="cubehelix") #sampling based on degree obtained

# %%
sns.countplot(y="educ", data=df, palette="cubehelix") #sampling based on years of education

# %%
sns.countplot(y="income06", data=df, palette="cubehelix") #sampling based on income

# %%
sns.countplot(x="happy", data=df, palette="cubehelix") #comparing counts on happiness levels

# %%
sns.countplot(x="cappun", data=df, palette="cubehelix") #comparing viewpoints on capital punishment

# %%
sns.countplot(x="gunlaw", data=df, palette="cubehelix") #comparing viewpoints on gun laws

# %%
sns.countplot(x="owngun", data=df, palette="cubehelix") #gun ownership counts

# %%
sns.countplot(x="helpblk", data=df, palette="cubehelix") #viewpoints on helping blacks

# %%
sns.countplot(y="affrmact", data=df, palette="cubehelix") #viewpoints on affirmative action

# %%
sns.countplot(x="voted08", data=df, palette="cubehelix") #voted in 2008 election

# %%
sns.countplot(y="region", data=df, palette="cubehelix") #region of America

# %%
sns.countplot(x="getahead", data=df, palette="cubehelix") #viewpoints on hard work and getting ahead

# %% [markdown]
# ### Comparing counts across multiple variables

# %%
sns.countplot(x="getahead", hue="race", data=df, palette="cubehelix") #viewpoints on hard work and getting ahead

# %%
sns.countplot(y="getahead", hue="race", data=df, palette="cubehelix") #comparing views on getting head by race

# %%
sns.countplot(y="relig2", hue="race", data=df, palette="cubehelix")

# %%
sns.countplot(y="colrac", hue="sex", data=df, palette="cubehelix") #allowing racists to teach views by sex

# %%
sns.countplot(y="colrac", hue="race", data=df, palette="cubehelix") #allowing racists to teach views by race

# %%
sns.countplot(y="colcom", hue="race", data=df, palette="husl") #allowing communists to teach views by race

# %%
sns.countplot(y="colmil", hue="race", data=df, palette="Set2") #allowing militarists to teach views by race

# %%
sns.countplot(y="colmil", hue="sex", data=df, palette="Set2") #allowing militarists to teach views by sex

# %%
sns.countplot(y="colhomo", hue="sex", data=df, palette="Set2") #allowing homosexual men to teach views by sex

# %%
sns.countplot(y="colhomo", hue="race", data=df, palette="Set2") #allowing homosexual men to teach views by race

# %%
sns.countplot(y="affrmact", hue="race", data=df, palette="Set2") #Comparing views on affirmative action by race

# %%
sns.countplot(y="affrmact", hue="sex", data=df, palette="Set2") #Comparing views on affirmative action by sex

# %%
sns.countplot(y="affrmact", hue="polviews", data=df, palette="Set2") 
#Comparing views on affirmative action by political views
#Question - how do views on affirmative action compare across political views?

# %%
sns.countplot(y="closewht", hue="race", data=df, palette="husl") 
#views on closeness to whites by race
# Question - are there significant differences in how races perceive their intra-race relationships?
# Question - how do different races rank their closeness to whites?

# %%
sns.countplot(y="closeblk", hue="race", data=df, palette="husl") 
#views on closeness to blacks by race
# Question - are there significant differences in how races perceive their intra-race relationships?
# Question - how do different races rank their closeness to blacks?

# %%
sns.countplot(y="helppoor", hue="polviews", data=df, palette="husl") 
#views on helping the poor by political party

# %% [markdown]
# ### Generating Strip Plots

# %%
sns.stripplot(x = "childs", y = "age", data = df, jitter = True);

# %%
sns.stripplot(x = "polviews", y = "age", data = df, jitter = True);

# %%
sns.stripplot(x = "tvhours", y = "race", data = df, jitter = True); #comparing tv hours and race

# %%
sns.stripplot(x = "natrace", y = "age", data = df, jitter = True); #comparing age with views on race

# %% [markdown]
# ### Generating Swarm Plots

# %%
sns.swarmplot(x="partyid", y="age", hue="race", data=df); 
# Question - How does party affliation differ by race?

# %%
sns.swarmplot(x="age", y="partyid", hue="race", data=df); 
#same as above, but with switched x and y axis (clarity?)

# %%
sns.swarmplot(x="partyid", y="age", hue="sex", data=df);

# %%
sns.swarmplot(x="natchld", y="age", hue="race", data=df);

# %%
sns.swarmplot(x="natchld", y="age", hue="sex", data=df);

# %%
sns.swarmplot(x="nataid", y="age", hue="partyid", data=df);
# Question - are there differences in viewpoints on how much the U.S. should spend on foreign aid by party?

# %%
sns.swarmplot(x="sex", y="age", hue="natchld", data=df);

# %%
sns.swarmplot(x="age", y="cappun", hue="race", data=df) 
# Observation - appears a higher proportion of blacks oppose capital punishment

# %%
sns.swarmplot(x="age", y="grass", hue="race", data=df)

# %%
sns.swarmplot(x="age", y="getahead", hue="race", data=df)

# %% [markdown]
# ### Generating multi-panel boxplots

# %%
sns.boxplot(x="age", y="educ", hue="race", data=df)

# %%
sns.boxplot(x="age", y="cappun", hue="sex", data=df) 
# Comparing views on capital punishment between gender and across age

# %%
sns.boxplot(x="age", y="cappun", hue="race", data=df)

# %%
sns.boxplot(x="age", y="grass", hue="sex", data=df)

# %%
sns.boxplot(x="age", y="grass", hue="race", data=df) # comparing views on legalization of marijuana across race and age

# %%
sns.boxplot(x="age", y="happy", hue="sex", data=df)

# %%
sns.boxplot(x="age", y="happy", hue="race", data=df)

# Question - Are there significant differences in peoples' reported happiness levels by race?

# %%
sns.violinplot(x="race", y="childs", data=df)

# %% [markdown]
# ### Multipanel Categorical Plots

# %% [markdown]
# #### Comparing viewings on AFFIRMATIVE ACTION across age, race, and gender

# %%
sns.factorplot(x="age", y="affrmact", hue="sex", col="race", data=df, kind="box", palette="cubehelix")

# Question - how does views on affirmative action differ across age, gender, and race?

# %%
sns.factorplot(x="age", y="affrmact", hue="sex", col="race", data=df, kind="swarm", palette='cubehelix')

# %%
sns.factorplot(x="age", y="affrmact", hue="natrace", col = "race", data=df, kind="swarm", palette='cubehelix')

# %%
sns.factorplot(x="age", y="affrmact", hue="race", col = "helpblk", data=df, kind="swarm", palette='cubehelix')

# %%
sns.factorplot(x="age", y="affrmact", hue="pres08", col = "race", data=df, kind="swarm", palette='cubehelix')

# %%
sns.factorplot(x="age", y="affrmact", hue="race", col = "polviews", data=df, kind="swarm", palette='cubehelix')

# %%
sns.factorplot(x="age", y="affrmact", hue="race", col = "partyid", data=df, kind="swarm", palette='cubehelix')

# %%
sns.factorplot(x="age", y="affrmact", hue="sex", col="race", data=df, kind="violin", palette="cubehelix")

# %% [markdown]
# #### Comparing views on AFFIRMATIVE ACTION across age, race, and views on hard work

# %%
sns.factorplot(x="age", y="affrmact", hue="race", col="getahead", data=df, kind="swarm", palette = "Set2")
# Question - do views on affirmative action differ across age? Do they differ across race? How do views on
# working hard to get ahead relate to peoples' views on affirmative action?

# %%
sns.factorplot(x="age", y="affrmact", hue="race", col="getahead", data=df, kind="violin", palette = "Set2")

# %% [markdown]
# ### Notes and examples from lab on Wednesday 11/22

# %%
x = np.linspace(0, 10, 50)

sin, = plt.plot(x, np.sin(x), '-.xc', label = "Sine") # -. is the line style, x is shape, and c is color
cos, = plt.plot(x, np.cos(x), '--dr', label = "Cosine") # -- is the line style, d is shape, and r is color
plt.xlabel('x')
plt.ylabel('Value')
plt.title('Trig Functions')
plt.legend(handles=[sin, cos])

plt.show()

# %%
x = np.linspace(0, 10, 50)

sin, = plt.plot(x, np.sin(x), '-.xc', label = "Sine") # -. is the line style, x is shape, and c is color
cos, = plt.plot(x, np.cos(x), '--dr', label = "Cosine") # -- is the line style, d is shape, and r is color
plt.xlabel('x')
plt.ylabel('Value')
plt.title('Trig Functions')
plt.legend(handles=[sin, cos])

plt.annotate('$(\pi, 0)$', xy=(np.pi,0), xytext=(4,0.75), arrowprops=dict(facecolor='black', shrink = 0.55)) 
# 0.75 determines the angle of the arrow
plt.show()

# %%
np.random.seed(3)
mu, sigma = 5, 3
y1s = mu + sigma*np.random.randn(50)
y2s = mu + sigma*np.random.randn(100000)
plt.subplot(2,1,1)
n,bins,patches = plt.hist(y1s,20,normed = 1) # n is the value of the histogram bins
print(n) #shows density at each bin
print(bins) #shows the bins
print(patches)
plt.subplot(2,1,2)
n2,bins,patches2 = plt.hist(y2s,20,normed = 1)
plt.show()
# Out:
# [ 0.06067233  0.          0.03033617  0.0910085   0.          0.12134466
#   0.0910085   0.12134466  0.182017    0.182017    0.15168083  0.0910085
#   0.06067233  0.06067233  0.03033617  0.0910085   0.03033617  0.03033617
#   0.03033617  0.06067233]
# [ -2.25724952  -1.59797043  -0.93869133  -0.27941224   0.37986685
#    1.03914595   1.69842504   2.35770413   3.01698323   3.67626232
#    4.33554141   4.99482051   5.6540996    6.3133787    6.97265779
#    7.63193688   8.29121598   8.95049507   9.60977416  10.26905326
#   10.92833235]
# <a list of 20 Patch objects>

# %%
N = 20000
xScatter = np.random.randn(N)
yScatter = np.random.randn(N)
alpha, beta = 1 + 2*np.random.rand(2)
yLinear = alpha + beta*xScatter + 2*np.random.randn(N)
yLinear2 = alpha + beta*xScatter + 4*np.random.randn(N)

# %%
plt.scatter(xScatter, yScatter)
plt.title('Independent Standard Normals')
plt.show()
print("alpha value is:", alpha)
print("beta value is:", beta)
# Out:
# alpha value is: 1.42079184447
# beta value is: 1.3350253979

# %%
plt.scatter(xScatter, yLinear)
plt.title('Need a title')
plt.show()

# %%
plt.scatter(xScatter, yLinear2)
plt.title('Need a title')
plt.show()

# %%
import statsmodels.api as sm

fig = sm.qqplot(yLinear, line = 's', fit = True) 
#draw straight line to see if it follows benchmark; after standardizing the data, if you have n draws, then 
plt.show()

# %%
tData = np.random.standard_t(3, N) #think of t distribution as the cousin of normal distribution with slightly more tail on it
figT = sm.qqplot(tData,line='s', fit = True)
plt.show()

# %%
uData = np.random.uniform(-2,2,N)
figU=sm.qqplot(uData, line='s', fit= True)
plt.show()
