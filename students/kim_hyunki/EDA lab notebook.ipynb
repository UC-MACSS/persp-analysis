# %% [markdown]
# # Hyun Ki Kim

# %% [markdown]
# # 11/27/2017

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
gss = pd.read_csv('gss2012.csv', index_col='id')

# %%
gss.shape
# Out:
# (1974, 220)

# %%
sorted(gss.columns)
# Out:
# ['abany',
#  'abdefect',
#  'abhlth',
#  'abnomore',
#  'abortion',
#  'abortion_3',
#  'abpoor',
#  'abrape',
#  'absingle',
#  'affrmact',
#  'affrmact2',
#  'age',
#  'age.f',
#  'age2',
#  'age_3',
#  'age_5',
#  'attend',
#  'attend2',
#  'attend3',
#  'attend7',
#  'authoritarianism',
#  'bible',
#  'black',
#  'black_traits',
#  'born',
#  'cappun',
#  'childs',
#  'closeblk',
#  'closeblk2',
#  'closewht',
#  'closewht2',
#  'cohort',
#  'colath',
#  'colcom',
#  'colhomo',
#  'colmil',
#  'colmslm',
#  'colrac',
#  'con_govt',
#  'conarmy',
#  'conbus',
#  'conclerg',
#  'coneduc',
#  'confed',
#  'confinan',
#  'conjudge',
#  'conlabor',
#  'conlegis',
#  'conmedic',
#  'conpress',
#  'consci',
#  'contv',
#  'courts',
#  'dateintv',
#  'degree',
#  'dem',
#  'divlaw',
#  'divlaw2',
#  'educ',
#  'educ_2',
#  'educ_4',
#  'egalit_scale',
#  'egalit_scale3',
#  'egalit_scale4',
#  'eqwlth',
#  'ethnic',
#  'evangelical',
#  'fechld',
#  'feelevel',
#  'feeused',
#  'fefam',
# ...

# %%
variable_of_interest = ['abany', 'age', 'age_5', 'bible', 'born', 'cappun', 'childs', 'cohort',
                        'divlaw2', 'educ', 'educ_4', 'ethnic', 'fund', 'fund2', 'getahead', 'god_r',
                        'gunlaw', 'happy', 'hispanic_2', 'homosex2', 'partyid_3', 'income06', 'kids',
                        'marital', 'owngun', 'polviews', 'postlife', 'premarsx', 'race', 'racial_liberal3',
                        'region', 'relig', 'relig2', 'rincom06_5', 'sex', 'sibs', 'spanking2',
                        'teensex', 'tvhours', 'tvhours5',' wordsum', 'xmarsex', 'zodiac']

# %%
sns.countplot('happy', data=gss)

# %%
sns.countplot('marital', data=gss)

# %%
sns.countplot('childs', data=gss)

# %%
sns.countplot('sibs', data=gss)

# %%
sns.countplot('age_5', data=gss)

# %%
sns.countplot('owngun', data=gss)

# %%
sns.countplot('relig2', data=gss)

# %%
sns.countplot('tvhours', data=gss)

# %%
sns.countplot('born', data=gss)

# %%
sns.countplot('divlaw2', data=gss)

# %%
sns.countplot('educ_4', data=gss)

# %%
sns.countplot('getahead', data=gss)

# %%
sns.countplot('gunlaw', data=gss)

# %%
sns.countplot('partyid_3', data=gss)

# %%
sns.countplot('polviews', data=gss)

# %%
sns.countplot('racial_liberal3', data=gss)

# %%
sns.countplot('rincom06_5', data=gss)

# %%
sns.countplot('spanking2', data=gss)

# %%
sns.countplot('teensex', data=gss)

# %%
sns.countplot('xmarsex', data=gss)

# %%
sns.countplot('abany', data=gss)

# %%
sns.countplot('zodiac', data=gss)

# %%
sns.countplot('region', data=gss)

# %% [markdown]
# # Thing that influence happiness

# %%
sns.countplot(x='race', hue='happy', data=gss)  # race matters

# %%
sns.countplot(x='educ_4', hue='happy', data=gss)  # education matters

# %%
sns.countplot(x='childs', hue='happy', data=gss)

# %%
sns.countplot(x='marital', hue='happy', data=gss)  # marital status matters

# %%
sns.countplot(x='rincom06_5', hue='happy', data=gss)  # income matters

# %%
sns.countplot(x='age_5', hue='happy', data=gss)

# %%
sns.countplot(x='kids', hue='happy', data=gss)

# %%
sns.countplot(x='postlife', hue='happy', data=gss)  # belief in life after death matters

# %%
sns.countplot(x='god_r', hue='happy', data=gss)

# %%
sns.countplot(x='relig2', hue='happy', data=gss)

# %%
sns.countplot(x='bible', hue='happy', data=gss)

# %%
sns.countplot(x='cappun', hue='happy', data=gss)

# %%
sns.countplot(x='premarsx', hue='happy', data=gss)

# %%
sns.countplot(x='getahead', hue='happy', data=gss)  # opinion of how people get ahead matters

# %%
sns.countplot(x='partyid_3', hue='happy', data=gss)  # political party affiliation matters

# %%
sns.countplot(x='polviews', hue='happy', data=gss)

# %%
sns.countplot(x='owngun', hue='happy', data=gss)

# %%
sns.countplot(x='gunlaw', hue='happy', data=gss)

# %%
sns.countplot(x='wordsum', hue='happy', data=gss)  # score on vocabulary test matters
